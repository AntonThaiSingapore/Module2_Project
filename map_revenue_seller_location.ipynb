# %%
### **Python Code**


import pandas as pd
import plotly.express as px

# 1. Define file path
file_path = "/home/anton/dsai/Module2_Project/data_mart/mart_seller_by_location.csv"

# 2. Load CSV into a Pandas DataFrame
df = pd.read_csv(file_path)


print("--- Top 5 Sellers Loaded ---")
print(df_top.head())

# 6. Build the Interactive Mapbox Bubble Map
fig = px.scatter_map(
    df_top,
    lat="latitude",
    lon="longitude",
    size="total_revenue",
    color="product_category_name_english" if "product_category_name_english" in df_top.columns else "state",
    hover_name="seller_id" if "seller_id" in df_top.columns else "city",
    hover_data={
        "city": True if "city" in df_top.columns else False,
        "state": True if "state" in df_top.columns else False,
        "total_orders": True,
        "total_revenue": ":,.2f",
        "latitude": False,
        "longitude": False
    },
    size_max=35,
    zoom=3.5,
    center={"lat": -14.2350, "lon": -51.9253},
    map_style="carto-positron",
    title="Top Sellers &amp; Categories by Revenue — Geospatial Map"
)

# 7. Format layout margins
fig.update_layout(
    margin={"r": 0, "t": 40, "l": 0, "b": 0},
    legend_title_text="Category"
)

# 8. Display interactive plot
fig.show()

# Optional: Save map as an interactive HTML file
fig.write_html("/home/anton/dsai/Module2_Project/top_sellers_map.html")
# Out:
# --- Top 5 Sellers Loaded ---
#      product_category_name_english                         seller_id  \
# 4525              office_furniture  7c67e1448b00f6e969d365cea6b010ab
# 6313                 watches_gifts  4869f7a5dfa277a7dca6462dcf3b52b2
# 6381                 watches_gifts  fa1c13f2614d7b5c4749cbc52fecda94
# 844                 bed_bath_table  4a3ca9315b744ce9f8e9374361493884
# 943                 bed_bath_table  da8622b14eb17ae2831f4ac5b9dab84a
#
#                  city state   latitude  longitude  total_revenue  total_orders
# 4525  itaquaquecetuba    SP -23.486111 -46.366721      217866.18             1
# 6313          guariba    SP -21.363502 -48.229601      216144.61             1
# 6381           sumare    SP -22.822137 -47.270335      198802.24             1
# 844          ibitinga    SP -21.757321 -48.829744      189813.77             1
# 943        piracicaba    SP -22.708702 -47.664701      173784.69             1
